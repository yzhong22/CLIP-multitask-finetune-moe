# %%
import os
import glob
from tqdm import tqdm

import pandas as pd

# %%
root = "/media/yesindeed/DATADRIVE1/mount/remote_cse/datasets/multitask-moe/CheXpert-v1.0-small/"

df = pd.read_csv(f"{root}/train.csv")

df
# Out:
#                                                      Path     Sex  Age  \
# 0       CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1       CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2       CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3       CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 4       CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
# ...                                                   ...     ...  ...
# 223409  CheXpert-v1.0-small/train/patient64537/study2/...    Male   59
# 223410  CheXpert-v1.0-small/train/patient64537/study1/...    Male   59
# 223411  CheXpert-v1.0-small/train/patient64538/study1/...  Female    0
# 223412  CheXpert-v1.0-small/train/patient64539/study1/...  Female    0
# 223413  CheXpert-v1.0-small/train/patient64540/study1/...  Female    0
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# 0              Frontal    AP         1.0                         NaN
# 1              Frontal    AP         NaN                         NaN
# 2              Frontal    AP         NaN                         NaN
# 3              Lateral   NaN         NaN                         NaN
# 4              Frontal    AP         NaN                         NaN
# ...                ...   ...         ...                         ...
# 223409         Frontal    AP         NaN                         NaN
# 223410         Frontal    AP         NaN                         NaN
# 223411         Frontal    AP         NaN                         NaN
# 223412         Frontal    AP         NaN                         NaN
# 223413         Frontal    AP         1.0                         NaN
#
#         Cardiomegaly  Lung Opacity  Lung Lesion  Edema  Consolidation  \
# 0                NaN           NaN          NaN    NaN            NaN
# 1               -1.0           1.0          NaN   -1.0           -1.0
# 2                NaN           1.0          NaN    NaN           -1.0
# 3                NaN           1.0          NaN    NaN           -1.0
# 4                NaN           NaN          NaN    1.0            NaN
# ...              ...           ...          ...    ...            ...
# 223409           NaN          -1.0          NaN    NaN            NaN
# 223410           NaN          -1.0          NaN    NaN            NaN
# 223411           NaN           NaN          NaN   -1.0            NaN
# 223412           1.0           1.0          NaN    NaN            NaN
# 223413           NaN           NaN          NaN    NaN            NaN
#
#         Pneumonia  Atelectasis  Pneumothorax  Pleural Effusion  Pleural Other  \
# 0             NaN          NaN           0.0               NaN            NaN
# 1             NaN         -1.0           NaN              -1.0            NaN
# 2             NaN          NaN           NaN               NaN            NaN
# 3             NaN          NaN           NaN               NaN            NaN
# 4             NaN          NaN           0.0               NaN            NaN
# ...           ...          ...           ...               ...            ...
# 223409        NaN         -1.0           0.0               1.0            NaN
# 223410        0.0         -1.0           NaN              -1.0            NaN
# 223411        NaN          NaN           NaN               NaN            NaN
# 223412       -1.0          1.0           0.0               NaN            NaN
# 223413        NaN          NaN           0.0               NaN            NaN
#
#         Fracture  Support Devices
# 0            NaN              1.0
# 1            1.0              NaN
# 2            1.0              NaN
# 3            1.0              NaN
# 4            NaN              NaN
# ...          ...              ...
# 223409       NaN              NaN
# 223410       NaN              NaN
# 223411       NaN              NaN
# 223412       NaN              0.0
# 223413       NaN              NaN
#
# [223414 rows x 19 columns]

# %%
df["Edema"].replace(-1, 1, inplace=True)
df["Edema"].fillna(0, inplace=True)

df["Atelectasis"].replace(-1, 1, inplace=True)
df["Atelectasis"].fillna(0, inplace=True)

df["Cardiomegaly"].replace(-1, 0, inplace=True)
df["Cardiomegaly"].fillna(0, inplace=True)

df["Consolidation"].replace(-1, 0, inplace=True)
df["Consolidation"].fillna(0, inplace=True)

df["Pleural Effusion"].replace(-1, 0, inplace=True)
df["Pleural Effusion"].fillna(0, inplace=True)

df["Pneumonia"].replace(-1, 0, inplace=True)
df["Pneumonia"].fillna(0, inplace=True)

df["Pneumothorax"].replace(-1, 0, inplace=True)
df["Pneumothorax"].fillna(0, inplace=True)

df["No Finding"].replace(-1, 0, inplace=True)
df["No Finding"].fillna(0, inplace=True)

df
# Out:
# /tmp/ipykernel_60490/3350457628.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Edema"].replace(-1, 1, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Edema"].fillna(0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Atelectasis"].replace(-1, 1, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Atelectasis"].fillna(0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Cardiomegaly"].replace(-1, 0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Cardiomegaly"].fillna(0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Consolidation"].replace(-1, 0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Consolidation"].fillna(0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Pleural Effusion"].replace(-1, 0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Pleural Effusion"].fillna(0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Pneumonia"].replace(-1, 0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Pneumonia"].fillna(0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Pneumothorax"].replace(-1, 0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Pneumothorax"].fillna(0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["No Finding"].replace(-1, 0, inplace=True)
# /tmp/ipykernel_60490/3350457628.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["No Finding"].fillna(0, inplace=True)
#                                                      Path     Sex  Age  \
# 0       CheXpert-v1.0-small/train/patient00001/study1/...  Female   68
# 1       CheXpert-v1.0-small/train/patient00002/study2/...  Female   87
# 2       CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 3       CheXpert-v1.0-small/train/patient00002/study1/...  Female   83
# 4       CheXpert-v1.0-small/train/patient00003/study1/...    Male   41
# ...                                                   ...     ...  ...
# 223409  CheXpert-v1.0-small/train/patient64537/study2/...    Male   59
# 223410  CheXpert-v1.0-small/train/patient64537/study1/...    Male   59
# 223411  CheXpert-v1.0-small/train/patient64538/study1/...  Female    0
# 223412  CheXpert-v1.0-small/train/patient64539/study1/...  Female    0
# 223413  CheXpert-v1.0-small/train/patient64540/study1/...  Female    0
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# 0              Frontal    AP         1.0                         NaN
# 1              Frontal    AP         0.0                         NaN
# 2              Frontal    AP         0.0                         NaN
# 3              Lateral   NaN         0.0                         NaN
# 4              Frontal    AP         0.0                         NaN
# ...                ...   ...         ...                         ...
# 223409         Frontal    AP         0.0                         NaN
# 223410         Frontal    AP         0.0                         NaN
# 223411         Frontal    AP         0.0                         NaN
# 223412         Frontal    AP         0.0                         NaN
# 223413         Frontal    AP         1.0                         NaN
#
#         Cardiomegaly  Lung Opacity  Lung Lesion  Edema  Consolidation  \
# 0                0.0           NaN          NaN    0.0            0.0
# 1                0.0           1.0          NaN    1.0            0.0
# 2                0.0           1.0          NaN    0.0            0.0
# 3                0.0           1.0          NaN    0.0            0.0
# 4                0.0           NaN          NaN    1.0            0.0
# ...              ...           ...          ...    ...            ...
# 223409           0.0          -1.0          NaN    0.0            0.0
# 223410           0.0          -1.0          NaN    0.0            0.0
# 223411           0.0           NaN          NaN    1.0            0.0
# 223412           1.0           1.0          NaN    0.0            0.0
# 223413           0.0           NaN          NaN    0.0            0.0
#
#         Pneumonia  Atelectasis  Pneumothorax  Pleural Effusion  Pleural Other  \
# 0             0.0          0.0           0.0               0.0            NaN
# 1             0.0          1.0           0.0               0.0            NaN
# 2             0.0          0.0           0.0               0.0            NaN
# 3             0.0          0.0           0.0               0.0            NaN
# 4             0.0          0.0           0.0               0.0            NaN
# ...           ...          ...           ...               ...            ...
# 223409        0.0          1.0           0.0               1.0            NaN
# 223410        0.0          1.0           0.0               0.0            NaN
# 223411        0.0          0.0           0.0               0.0            NaN
# 223412        0.0          1.0           0.0               0.0            NaN
# 223413        0.0          0.0           0.0               0.0            NaN
#
#         Fracture  Support Devices
# 0            NaN              1.0
# 1            1.0              NaN
# 2            1.0              NaN
# 3            1.0              NaN
# 4            NaN              NaN
# ...          ...              ...
# 223409       NaN              NaN
# 223410       NaN              NaN
# 223411       NaN              NaN
# 223412       NaN              0.0
# 223413       NaN              NaN
#
# [223414 rows x 19 columns]

# %%
dict_out = {"id": [], "exam_id": [], "path": [], "class": [], "exam_class": [], "patient": []}

target_diseases = ["Cardiomegaly", "Edema", "Consolidation", "Atelectasis", "Pleural Effusion", "Pneumothorax"]

for i in range(len(df)):
    item = df.iloc[i]

    path = item["Path"]
    img_path = path.replace("CheXpert-v1.0-small/", "./")

    assert os.path.exists(f"{root}/{img_path.replace('./', '')}")

    patient, study, img = path.split("/")[-3:]

    if item["No Finding"] == 1:
        cls = "no findings"
    else:
        cls = []
        if item["Cardiomegaly"] == 1:
            cls.append("cardiomegaly")
        if item["Edema"] == 1:
            cls.append("edema")
        if item["Consolidation"] == 1:
            cls.append("consolidation")
        if item["Atelectasis"] == 1:
            cls.append("atelectasis")
        if item["Pleural Effusion"] == 1:
            cls.append("pleural effusion")
        # if item["Pneumonia"] == 1:
        #     cls.append("pneumonia")
        if item["Pneumothorax"] == 1:
            cls.append("pneumothorax")

        if len(cls) > 0:
            cls = ", ".join(cls)
        else:
            continue

    dict_out["id"].append(f"{patient}/{study}/{img.replace('.jpg', '')}")
    dict_out["exam_id"].append(f"{patient}/{study}/{img.replace('.jpg', '')}")

    dict_out["path"].append(img_path)
    dict_out["patient"].append(patient)

    dict_out["class"].append(cls)
    dict_out["exam_class"].append(cls)

df_out = pd.DataFrame.from_dict(dict_out)
df_out.head()

# %%
df_out.to_csv(f"{root}/temp.csv", index=False)

# %%
df_out = pd.read_csv(f"{root}/temp.csv")

# %%
import numpy as np

df_out["dataset"] = "chexpert"
df_out["class_num"] = 7
df_out["contains_negative"] = 1
df_out["modality"] = "xray"

df_out = df_out.sample(frac=1).reset_index(drop=True)

patients = df_out["patient"].unique()
patient_size = len(patients)

test_indices = np.random.choice(
    list(range(patient_size)), int(patient_size * 0.15), replace=False)

test_patients = patients[test_indices]

df_out["split"] = "train"

df_out.loc[df_out["patient"].isin(test_patients), "split"] = "test"

# %%
df_out["split"].value_counts()
# Out:
# split
# train    161874
# test      28211
# Name: count, dtype: int64

# %%
df_out = df_out.drop("patient", axis=1)

df_out.to_csv(f"{root}/metadata.csv", index=False)

# %%
print(df_out["class"].value_counts())
# Out:
# class
# pleural effusion                                                   24119
# no findings                                                        22381
# atelectasis                                                        19729
# edema                                                              17958
# atelectasis, pleural effusion                                      15684
#                                                                    ...
# cardiomegaly, edema, consolidation, atelectasis, pneumothorax          2
# edema, consolidation, atelectasis, pneumonia, pneumothorax             1
# edema, consolidation, pleural effusion, pneumonia, pneumothorax        1
# edema, consolidation, pneumonia, pneumothorax                          1
# cardiomegaly, edema, pneumonia, pneumothorax                           1
# Name: count, Length: 112, dtype: int64

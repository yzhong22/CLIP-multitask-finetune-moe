# %%
import PIL.Image as pil_image
from PIL import Image
import io
import numpy as np

import matplotlib.pyplot as plt

# %%
path = "/media/yesindeed/WD5T/download/137covid_patient49_SR_2_IM00025.tif"
save_path = "path to save the Visualizable image"
with open(path, "rb") as f:
    tif = pil_image.open(io.BytesIO(f.read()))
array = np.array(tif)
max_val = np.amax(array)
normalized = array / max_val

# %%
plt.imshow(normalized, "gray")

# %%
tif = Image.open(path)

array = np.array(tif) - 1024
print(np.min(array))
print(np.max(array))
array = np.clip(array, -1000, 1000)
# normalized = (array + 1000) / 2000

plt.imshow(array, "gray")
# Out:
# 0
# 65535

# %%
import pydicom

dicom = pydicom.dcmread("/media/yesindeed/WD5T/download/451fc5923b1f/d693a6172d97.dcm")
img = dicom.pixel_array * dicom.RescaleSlope + dicom.RescaleIntercept
img = np.clip(img, -1000, 500)

plt.imshow(img, "gray")

# %%
import numpy as np
import pydicom

import matplotlib.pyplot as plt

# %%
file = "/media/yesindeed/DATADRIVE1/mount/remote_cse/datasets/multitask-moe/rsna-str-pulmonary-embolism-detection/test/0b0425dda4cc/29843553ef87/1bb3e92b73c5.dcm"

dicom = pydicom.dcmread(file)
array = dicom.pixel_array

print(array)
print(dicom.RescaleSlope)
print(dicom.RescaleIntercept)

array = np.clip(array * dicom.RescaleSlope + dicom.RescaleIntercept, -600 - 750, 150)

plt.imshow(array, "gray")
# Out:
# [[-2000 -2000 -2000 ... -2000 -2000 -2000]
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]
#  ...
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]
#  [-2000 -2000 -2000 ... -2000 -2000 -2000]]
# 1
# -1024
